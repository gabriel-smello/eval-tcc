# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# %pip install -e .

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %%
# !unzip -q /content/drive/MyDrive/tcc/YOLOv8/coffee.v2i.yolov8.zip -d /content/data

# %%
import yaml
with open('./config.yaml', 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])
num_classes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9b0f94956cf0> in <cell line: 2>()
#       1 import yaml
# ----> 2 with open('./config.yaml', 'r') as stream:
#       3     num_classes = str(yaml.safe_load(stream)['nc'])
#       4 num_classes
#
# FileNotFoundError: [Errno 2] No such file or directory: './config.yaml'

# %%
project = "/content/drive/MyDrive/tcc/YOLOv8/runs"
name = "c2f2p6-"

# %%
# !yolo train model=yolov8n-seg.yaml data=/content/data/data.yaml epochs=100 imgsz=640 batch=4 patience=100
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !yolo val data=/content/data/data.yaml model=/content/drive/MyDrive/tcc/YOLOv8/runs/100_epochs-3/weights/best.pt
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3258844 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/data/valid/labels... 40 images, 8 backgrounds, 0 corrupt: 100% 40/40 [00:00<00:00, 1268.88it/s]
# val: New cache created: /content/data/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 3/3 [00:03<00:00,  1.21s/it]
#                    all         40        206      0.872      0.559      0.744       0.46      0.612      0.681      0.752      0.396
#             cercospora         40         46      0.813      0.261      0.499      0.328      0.656      0.413      0.555      0.346
#                  miner         40        132          1      0.122      0.591      0.289      0.696      0.386      0.568      0.215
# ...

# %%
# !yolo val data=/content/data/data.yaml model=/content/drive/MyDrive/tcc/YOLOv8/runs/c2f2/weights/best.pt
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 2062738 parameters, 0 gradients, 9.0 GFLOPs
# val: Scanning /content/data/valid/labels.cache... 40 images, 8 backgrounds, 0 corrupt: 100% 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.59s/it]
#                    all         40        206      0.715      0.678      0.771      0.524      0.725      0.664      0.771      0.439
#             cercospora         40         46      0.561      0.435      0.543       0.37      0.568      0.435      0.572      0.355
#                  miner         40        132      0.794       0.35      0.631      0.288      0.779      0.294      0.602      0.228
# ...

# %%
# !yolo val data=/content/data/data.yaml model=/content/drive/MyDrive/tcc/YOLOv8/runs/c2f2p6/segment/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8-seg-p6 summary (fused): 253 layers, 5094592 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/data/valid/labels.cache... 40 images, 8 backgrounds, 0 corrupt: 100% 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 3/3 [00:04<00:00,  1.42s/it]
#                    all         40        206       0.64      0.708      0.756       0.46      0.625      0.693      0.742      0.447
#             cercospora         40         46      0.605      0.478      0.578      0.381      0.605      0.478      0.577      0.383
#                  miner         40        132      0.694      0.499      0.611       0.28      0.663      0.476      0.586      0.231
# ...

# %%
import pandas as pd

# %%
yolov8 = pd.read_csv('/content/drive/MyDrive/tcc/YOLOv8/runs/100_epochs-3/results.csv')
yolov8.sort_values(by='       metrics/mAP50(M)', ascending=False)[['   metrics/precision(M)','      metrics/recall(M)','       metrics/mAP50(M)','    metrics/mAP50-95(M)']]
# Out:
#        metrics/precision(M)        metrics/recall(M)         metrics/mAP50(M)  \
# 97                  0.62585                  0.69577                  0.77490
# 70                  0.61956                  0.67317                  0.77342
# 73                  0.72405                  0.70193                  0.77011
# 83                  0.72031                  0.71340                  0.76953
# 68                  0.71959                  0.64437                  0.76705
# ..                      ...                      ...                      ...
# 3                   0.52294                  0.15740                  0.14499
# 4                   0.18322                  0.17142                  0.13119
# 2                   0.47318                  0.10902                  0.10719
# 1                   0.53351                  0.01552                  0.02913
# 0                   0.00000                  0.00000                  0.00000
#
#         metrics/mAP50-95(M)
# ...

# %%
c2f2 = pd.read_csv('/content/drive/MyDrive/tcc/YOLOv8/runs/c2f2/results.csv')
c2f2.sort_values(by='       metrics/mAP50(M)', ascending=False)[['   metrics/precision(M)','      metrics/recall(M)','       metrics/mAP50(M)','    metrics/mAP50-95(M)']]
# Out:
#        metrics/precision(M)        metrics/recall(M)         metrics/mAP50(M)  \
# 74                  0.74999                  0.65268                  0.77137
# 83                  0.61317                  0.69027                  0.75508
# 66                  0.64802                  0.70914                  0.75495
# 73                  0.64765                  0.70810                  0.75477
# 68                  0.70356                  0.66353                  0.75401
# ..                      ...                      ...                      ...
# 4                   0.42969                  0.26867                  0.18493
# 3                   0.48754                  0.18736                  0.16691
# 2                   0.19034                  0.21692                  0.11269
# 1                   0.43561                  0.06857                  0.05195
# 0                   0.00000                  0.00000                  0.00000
#
#         metrics/mAP50-95(M)
# ...

# %%
c2f2p6 = pd.read_csv('/content/drive/MyDrive/tcc/YOLOv8/runs/c2f2p6/segment/train/results.csv')
c2f2p6.sort_values(by='       metrics/mAP50(M)', ascending=False)[['   metrics/precision(M)','      metrics/recall(M)','       metrics/mAP50(M)','    metrics/mAP50-95(M)']]
# Out:
#        metrics/precision(M)        metrics/recall(M)         metrics/mAP50(M)  \
# 95                  0.79298                  0.59651                  0.78198
# 87                  0.68055                  0.68410                  0.78082
# 88                  0.78627                  0.66611                  0.77951
# 86                  0.74604                  0.62016                  0.77346
# 89                  0.71217                  0.70321                  0.76991
# ..                      ...                      ...                      ...
# 4                   0.46647                  0.27185                  0.17527
# 3                   0.46146                  0.24388                  0.13887
# 2                   0.10245                  0.06571                  0.04768
# 1                   0.78475                  0.02174                  0.02600
# 0                   0.00000                  0.00000                  0.00000
#
#         metrics/mAP50-95(M)
# ...

# %%
from matplotlib import pyplot as plt
from PIL import Image
from IPython.display import Image

# %%
Image("/content/drive/MyDrive/tcc/YOLOv8/runs/100_epochs-2/results.png")

# %%
Image(filename='/content/drive/MyDrive/tcc/YOLOv8/runs/100_epochs-2/train_batch7381.jpg', width=900)
